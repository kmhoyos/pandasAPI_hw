# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "&units=imperial"

name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed =[]

for city in cities:
    
    try:
        response = requests.get(url + "appid=" + api_key + units + "&q=" + city).json()
        name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp"])
        wind_speed.append(response["wind"]["speed"])
        print(f"{city} was a success")

    except:
        print("No data")
    
    print("------------")
# Out:
# hammerfest was a success
# ------------
# mataura was a success
# ------------
# hobart was a success
# ------------
# nikolskoye was a success
# ------------
# punta arenas was a success
# ------------
# grindavik was a success
# ------------
# No data
# ------------
# bluff was a success
# ------------
# puerto ayora was a success
# ------------
# atuona was a success
# ------------
# geraldton was a success
# ------------
# lorengau was a success
# ------------
# port lincoln was a success
# ------------
# saint-joseph was a success
# ------------
# kidal was a success
# ------------
# albany was a success
# ------------
# kapaa was a success
# ------------
# vaini was a success
# ------------
# ushuaia was a success
# ------------
# faanui was a success
# ------------
# tyukhtet was a success
# ------------
# fukue was a success
# ------------
# tasiilaq was a success
# ------------
# mar del plata was a success
# ------------
# east london was a success
# ------------
# saint-louis was a success
# ------------
# broken hill was a success
# ------------
# dakar was a success
# ------------
# No data
# ------------
# cape town was a success
# ------------
# camacha was a success
# ------------
# salalah was a success
# ------------
# airai was a success
# ------------
# nusaybin was a success
# ------------
# castro was a success
# ------------
# No data
# ------------
# troitskoye was a success
# ------------
# butaritari was a success
# ------------
# rikitea was a success
# ------------
# marawi was a success
# ------------
# provideniya was a success
# ------------
# yellowknife was a success
# ------------
# chokurdakh was a success
# ------------
# high rock was a success
# ------------
# tuatapere was a success
# ------------
# buraydah was a success
# ------------
# lasa was a success
# ------------
# richards bay was a success
# ------------
# chicama was a success
# ------------
# No data
# ------------
# changping was a success
# ------------
# rio grande was a success
# ------------
# bilibino was a success
# ------------
# aswan was a success
# ------------
# naze was a success
# ------------
# erenhot was a success
# ------------
# tiksi was a success
# ------------
# weyburn was a success
# ------------
# mount isa was a success
# ------------
# No data
# ------------
# saint-philippe was a success
# ------------
# carnarvon was a success
# ------------
# morlaix was a success
# ------------
# avarua was a success
# ------------
# fortuna was a success
# ------------
# husavik was a success
# ------------
# aasiaat was a success
# ------------
# yulara was a success
# ------------
# finnentrop was a success
# ------------
# ribeira grande was a success
# ------------
# georgetown was a success
# ------------
# No data
# ------------
# eureka was a success
# ------------
# ostrovnoy was a success
# ------------
# bagotville was a success
# ------------
# eyl was a success
# ------------
# petropavlovsk-kamchatskiy was a success
# ------------
# bethel was a success
# ------------
# thompson was a success
# ------------
# nuuk was a success
# ------------
# No data
# ------------
# clyde river was a success
# ------------
# moerai was a success
# ------------
# totma was a success
# ------------
# turbat was a success
# ------------
# taltal was a success
# ------------
# prince rupert was a success
# ------------
# kavieng was a success
# ------------
# hithadhoo was a success
# ------------
# No data
# ------------
# port alfred was a success
# ------------
# mahebourg was a success
# ------------
# kodiak was a success
# ------------
# jamestown was a success
# ------------
# sept-iles was a success
# ------------
# No data
# ------------
# saldanha was a success
# ------------
# No data
# ------------
# busselton was a success
# ------------
# mogadishu was a success
# ------------
# port elizabeth was a success
# ------------
# petropavl was a success
# ------------
# No data
# ------------
# dongying was a success
# ------------
# hohhot was a success
# ------------
# No data
# ------------
# khorixas was a success
# ------------
# sheopur was a success
# ------------
# guerrero negro was a success
# ------------
# tadine was a success
# ------------
# No data
# ------------
# te anau was a success
# ------------
# lydenburg was a success
# ------------
# miracatu was a success
# ------------
# bredasdorp was a success
# ------------
# No data
# ------------
# No data
# ------------
# san cristobal was a success
# ------------
# namatanai was a success
# ------------
# mbandaka was a success
# ------------
# longyearbyen was a success
# ------------
# saskylakh was a success
# ------------
# portland was a success
# ------------
# ilam was a success
# ------------
# dikson was a success
# ------------
# seddon was a success
# ------------
# barrow was a success
# ------------
# axim was a success
# ------------
# takoradi was a success
# ------------
# ouadda was a success
# ------------
# popondetta was a success
# ------------
# hermanus was a success
# ------------
# port hedland was a success
# ------------
# vila velha was a success
# ------------
# kieta was a success
# ------------
# No data
# ------------
# klaeng was a success
# ------------
# ilebo was a success
# ------------
# new norfolk was a success
# ------------
# cherkasskoye was a success
# ------------
# sorong was a success
# ------------
# ballina was a success
# ------------
# No data
# ------------
# hervey bay was a success
# ------------
# No data
# ------------
# akureyri was a success
# ------------
# iqaluit was a success
# ------------
# arman was a success
# ------------
# klaksvik was a success
# ------------
# firminy was a success
# ------------
# upernavik was a success
# ------------
# No data
# ------------
# valledupar was a success
# ------------
# carutapera was a success
# ------------
# west bay was a success
# ------------
# No data
# ------------
# arraial do cabo was a success
# ------------
# kalianget was a success
# ------------
# chuy was a success
# ------------
# hasaki was a success
# ------------
# port blair was a success
# ------------
# lompoc was a success
# ------------
# mahon was a success
# ------------
# hofn was a success
# ------------
# kapurthala was a success
# ------------
# ladario was a success
# ------------
# hilo was a success
# ------------
# san patricio was a success
# ------------
# taoudenni was a success
# ------------
# gua musang was a success
# ------------
# rio gallegos was a success
# ------------
# No data
# ------------
# waipawa was a success
# ------------
# krasnaya gora was a success
# ------------
# strezhevoy was a success
# ------------
# manjacaze was a success
# ------------
# No data
# ------------
# quetigny was a success
# ------------
# jacareacanga was a success
# ------------
# namie was a success
# ------------
# lagoa was a success
# ------------
# cherskiy was a success
# ------------
# No data
# ------------
# victoria was a success
# ------------
# port hardy was a success
# ------------
# oum hadjer was a success
# ------------
# No data
# ------------
# panama city was a success
# ------------
# christchurch was a success
# ------------
# No data
# ------------
# bambous virieux was a success
# ------------
# batagay was a success
# ------------
# tynda was a success
# ------------
# cacu was a success
# ------------
# kupang was a success
# ------------
# qaanaaq was a success
# ------------
# buchanan was a success
# ------------
# itarema was a success
# ------------
# zabol was a success
# ------------
# isla mujeres was a success
# ------------
# karratha was a success
# ------------
# havoysund was a success
# ------------
# No data
# ------------
# katsuura was a success
# ------------
# ust-maya was a success
# ------------
# pisco was a success
# ------------
# tessalit was a success
# ------------
# shelburne was a success
# ------------
# santa rosalia was a success
# ------------
# faya was a success
# ------------
# bernburg was a success
# ------------
# komsomolskiy was a success
# ------------
# souillac was a success
# ------------
# No data
# ------------
# coihaique was a success
# ------------
# mayya was a success
# ------------
# bintulu was a success
# ------------
# shimoda was a success
# ------------
# No data
# ------------
# khatanga was a success
# ------------
# chara was a success
# ------------
# vila franca do campo was a success
# ------------
# vestmanna was a success
# ------------
# nantucket was a success
# ------------
# mongoumba was a success
# ------------
# No data
# ------------
# calama was a success
# ------------
# pacific grove was a success
# ------------
# havre-saint-pierre was a success
# ------------
# No data
# ------------
# hovd was a success
# ------------
# pevek was a success
# ------------
# sunnyside was a success
# ------------
# kaitangata was a success
# ------------
# mabai was a success
# ------------
# kirensk was a success
# ------------
# norman wells was a success
# ------------
# rocha was a success
# ------------
# vestmannaeyjar was a success
# ------------
# khash was a success
# ------------
# No data
# ------------
# viransehir was a success
# ------------
# No data
# ------------
# mehamn was a success
# ------------
# port-gentil was a success
# ------------
# sarkand was a success
# ------------
# No data
# ------------
# bathsheba was a success
# ------------
# buin was a success
# ------------
# karaton was a success
# ------------
# ostersund was a success
# ------------
# No data
# ------------
# No data
# ------------
# ahipara was a success
# ------------
# ulety was a success
# ------------
# touros was a success
# ------------
# verkhoyansk was a success
# ------------
# los llanos de aridane was a success
# ------------
# iskateley was a success
# ------------
# viseu was a success
# ------------
# saint-pierre was a success
# ------------
# snezhnogorsk was a success
# ------------
# bilma was a success
# ------------
# teguise was a success
# ------------
# reconquista was a success
# ------------
# zabaykalsk was a success
# ------------
# No data
# ------------
# No data
# ------------
# coruripe was a success
# ------------
# esfahan was a success
# ------------
# vinh long was a success
# ------------
# lebu was a success
# ------------
# vieux fort was a success
# ------------
# altay was a success
# ------------
# pskov was a success
# ------------
# diffa was a success
# ------------
# cambuci was a success
# ------------
# No data
# ------------
# tocopilla was a success
# ------------
# narsaq was a success
# ------------
# saint george was a success
# ------------
# No data
# ------------
# abha was a success
# ------------
# catuday was a success
# ------------
# lake cowichan was a success
# ------------
# evensk was a success
# ------------
# aklavik was a success
# ------------
# No data
# ------------
# oriximina was a success
# ------------
# haapiti was a success
# ------------
# zhanaozen was a success
# ------------
# No data
# ------------
# nieuw amsterdam was a success
# ------------
# yinchuan was a success
# ------------
# asyut was a success
# ------------
# turukhansk was a success
# ------------
# long beach was a success
# ------------
# bereda was a success
# ------------
# constitucion was a success
# ------------
# san policarpo was a success
# ------------
# hambantota was a success
# ------------
# alofi was a success
# ------------
# kota kinabalu was a success
# ------------
# talnakh was a success
# ------------
# pangkalanbuun was a success
# ------------
# bilecik was a success
# ------------
# wanxian was a success
# ------------
# dukat was a success
# ------------
# praia da vitoria was a success
# ------------
# tafresh was a success
# ------------
# ilulissat was a success
# ------------
# yuli was a success
# ------------
# awjilah was a success
# ------------
# yerbogachen was a success
# ------------
# makakilo city was a success
# ------------
# batemans bay was a success
# ------------
# severo-kurilsk was a success
# ------------
# No data
# ------------
# ambon was a success
# ------------
# hamilton was a success
# ------------
# neiafu was a success
# ------------
# chifeng was a success
# ------------
# anadyr was a success
# ------------
# svetlogorsk was a success
# ------------
# murgab was a success
# ------------
# artyom was a success
# ------------
# gadoros was a success
# ------------
# No data
# ------------
# quelimane was a success
# ------------
# mareeba was a success
# ------------
# No data
# ------------
# hokitika was a success
# ------------
# ormara was a success
# ------------
# black diamond was a success
# ------------
# kavaratti was a success
# ------------
# imeni poliny osipenko was a success
# ------------
# cabo san lucas was a success
# ------------
# cidreira was a success
# ------------
# moron was a success
# ------------
# solnechnyy was a success
# ------------
# tarut was a success
# ------------
# No data
# ------------
# caxito was a success
# ------------
# yumen was a success
# ------------
# paamiut was a success
# ------------
# butterworth was a success
# ------------
# aykhal was a success
# ------------
# alugan was a success
# ------------
# salvador was a success
# ------------
# auki was a success
# ------------
# sitka was a success
# ------------
# sibolga was a success
# ------------
# menongue was a success
# ------------
# anito was a success
# ------------
# plettenberg bay was a success
# ------------
# berekua was a success
# ------------
# kudahuvadhoo was a success
# ------------
# mendoza was a success
# ------------
# port augusta was a success
# ------------
# caohe was a success
# ------------
# karasjok was a success
# ------------
# la macarena was a success
# ------------
# esperance was a success
# ------------
# sangar was a success
# ------------
# tuktoyaktuk was a success
# ------------
# poltavka was a success
# ------------
# marzuq was a success
# ------------
# san ramon de la nueva oran was a success
# ------------
# mandalgovi was a success
# ------------
# coquimbo was a success
# ------------
# neuquen was a success
# ------------
# pinhao was a success
# ------------
# sinazongwe was a success
# ------------
# No data
# ------------
# pangoa was a success
# ------------
# nanortalik was a success
# ------------
# leh was a success
# ------------
# kyshtovka was a success
# ------------
# akdagmadeni was a success
# ------------
# luderitz was a success
# ------------
# No data
# ------------
# sao filipe was a success
# ------------
# cabrera was a success
# ------------
# okhotsk was a success
# ------------
# kondinskoye was a success
# ------------
# kruisfontein was a success
# ------------
# salihorsk was a success
# ------------
# No data
# ------------
# No data
# ------------
# tura was a success
# ------------
# sioux lookout was a success
# ------------
# verkhniye tatyshly was a success
# ------------
# No data
# ------------
# mantua was a success
# ------------
# senneterre was a success
# ------------
# sur was a success
# ------------
# No data
# ------------
# wuhu was a success
# ------------
# kahului was a success
# ------------
# No data
# ------------
# iisalmi was a success
# ------------
# morris was a success
# ------------
# newport was a success
# ------------
# neyshabur was a success
# ------------
# la tuque was a success
# ------------
# pundaguitan was a success
# ------------
# krasnovka was a success
# ------------
# bandarbeyla was a success
# ------------
# parry sound was a success
# ------------
# leshukonskoye was a success
# ------------
# No data
# ------------
# lovozero was a success
# ------------
# ayan was a success
# ------------
# tenenkou was a success
# ------------
# ponta do sol was a success
# ------------
# la asuncion was a success
# ------------
# narbonne was a success
# ------------
# ust-nera was a success
# ------------
# dudinka was a success
# ------------
# terrace was a success
# ------------
# palmer was a success
# ------------
# joshimath was a success
# ------------
# gobabis was a success
# ------------
# bonfim was a success
# ------------
# kualakapuas was a success
# ------------
# big spring was a success
# ------------
# sinnamary was a success
# ------------
# aloleng was a success
# ------------
# santa maria was a success
# ------------
# mount gambier was a success
# ------------
# No data
# ------------
# cayenne was a success
# ------------
# namibe was a success
# ------------
# alamosa was a success
# ------------
# port-cartier was a success
# ------------
# severobaykalsk was a success
# ------------
# novoagansk was a success
# ------------
# tigil was a success
# ------------
# kedrovyy was a success
# ------------
# sabya was a success
# ------------
# virginia beach was a success
# ------------
# caldas novas was a success
# ------------
# jiexiu was a success
# ------------
# aguimes was a success
# ------------
# bolshevik was a success
# ------------
# kedougou was a success
# ------------
# avera was a success
# ------------
# raudeberg was a success
# ------------
# maniwaki was a success
# ------------
# ossora was a success
# ------------
# No data
# ------------
# iquitos was a success
# ------------
# amapa was a success
# ------------
# flinders was a success
# ------------
# simao was a success
# ------------
# No data
# ------------
# watsa was a success
# ------------
# daru was a success
# ------------
# ancud was a success
# ------------
# No data
# ------------
# arroyo was a success
# ------------
# ouidah was a success
# ------------
# alihe was a success
# ------------
# sakharovo was a success
# ------------
# torbay was a success
# ------------
# noumea was a success
# ------------
# jieshi was a success
# ------------
# paris was a success
# ------------
# dalvik was a success
# ------------
# lehigh acres was a success
# ------------
# mossendjo was a success
# ------------
# No data
# ------------
# waddan was a success
# ------------
# jalingo was a success
# ------------
# nome was a success
# ------------
# lamu was a success
# ------------
# fort nelson was a success
# ------------
# svetlaya was a success
# ------------
# bubaque was a success
# ------------
# artvin was a success
# ------------
# puerto leguizamo was a success
# ------------
# sarahan was a success
# ------------
# berlevag was a success
# ------------
# marsa matruh was a success
# ------------
# broome was a success
# ------------
# dzheguta was a success
# ------------
# qaqortoq was a success
# ------------
# acapulco was a success
# ------------
# leningradskiy was a success
# ------------
# rawson was a success
# ------------
# khandbari was a success
# ------------
# jashpurnagar was a success
# ------------
# No data
# ------------
# anqing was a success
# ------------
# isangel was a success
# ------------
# ouro preto do oeste was a success
# ------------
# ussel was a success
# ------------
# fuling was a success
# ------------
# luwuk was a success
# ------------
# tazovskiy was a success
# ------------
# huilong was a success
# ------------
# nishihara was a success
# ------------
# kushiro was a success
# ------------
# puerto escondido was a success
# ------------
# nuevitas was a success
# ------------
# belomorsk was a success
# ------------
# salina cruz was a success
# ------------
# hudiksvall was a success
# ------------
# ozernovskiy was a success
# ------------
# barcelos was a success
# ------------
# No data
# ------------
# lapa was a success
# ------------
# cururupu was a success
# ------------
# grand-santi was a success
# ------------
# mragowo was a success
# ------------
# poum was a success
# ------------
# stubbekobing was a success
# ------------
# penzance was a success
# ------------
# hereford was a success
# ------------
# bagdarin was a success
# ------------
# cumra was a success
# ------------
# belyy yar was a success
# ------------
# balabac was a success
# ------------
# hrebinka was a success
# ------------
# astara was a success
# ------------
# katobu was a success
# ------------
# mecca was a success
# ------------
# calvinia was a success
# ------------
# bambanglipuro was a success
# ------------
# No data
# ------------
# nouadhibou was a success
# ------------
# montalvo was a success
# ------------
# natal was a success
# ------------
# nekhayevskiy was a success
# ------------
# winslow was a success
# ------------
# lubango was a success
# ------------
# adrar was a success
# ------------
# manavalakurichi was a success
# ------------
# olinda was a success
# ------------
# buta was a success
# ------------
# singaraja was a success
# ------------
# middle island was a success
# ------------
# antofagasta was a success
# ------------
# alice springs was a success
# ------------
# pontes e lacerda was a success
# ------------
# kununurra was a success
# ------------
# laela was a success
# ------------
# lavrentiya was a success
# ------------
# karonga was a success
# ------------
# la ronge was a success
# ------------
# coracao de jesus was a success
# ------------
# nabire was a success
# ------------
# dingle was a success
# ------------
# stutterheim was a success
# ------------
# ahuimanu was a success
# ------------
# peterhead was a success
# ------------
# fairbanks was a success
# ------------
# quatre cocos was a success
# ------------
# darhan was a success
# ------------
# half moon bay was a success
# ------------
# paoua was a success
# ------------
# verkhnevilyuysk was a success
# ------------
# new baltimore was a success
# ------------
# bandundu was a success
# ------------
# jalu was a success
# ------------
# teya was a success
# ------------
# codrington was a success
# ------------
# clovis was a success
# ------------
# qandala was a success
# ------------
# okha was a success
# ------------
# the valley was a success
# ------------
# sambava was a success
# ------------
# alta floresta was a success
# ------------
# cordoba was a success
# ------------
# butajira was a success
# ------------
# deputatskiy was a success
# ------------
# seoul was a success
# ------------
# chiredzi was a success
# ------------
# moree was a success
# ------------
# imamoglu was a success
# ------------
# bage was a success
# ------------
# No data
# ------------
# porto novo was a success
# ------------
# riohacha was a success
# ------------
# jacmel was a success
# ------------
# No data
# ------------
# goroka was a success
# ------------
# birjand was a success
# ------------
# orotukan was a success
# ------------
# seguin was a success
# ------------
# muyezerskiy was a success
# ------------
# wagga wagga was a success
# ------------
# rodino was a success
# ------------
# sakaiminato was a success
# ------------
# pudozh was a success
# ------------
# san martin was a success
# ------------
# altamira was a success
# ------------
# manokwari was a success
# ------------
# semey was a success
# ------------
# dzhebariki-khaya was a success
# ------------
# batagay-alyta was a success
# ------------
# japura was a success
# ------------
# vao was a success
# ------------
# nurlat was a success
# ------------
# xushan was a success
# ------------
# pontianak was a success
# ------------
# tomatlan was a success
# ------------
# magnor was a success
# ------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = {"City": name, "Country": country, "Date": date, "Longitude": lng, "Latitude": lat, "Cloudiness": cloudiness, "Humidity": humidity, "Max Temp": max_temp, "Wind Speed": wind_speed}
weather_data = pd.DataFrame(weather_data)

weather_data.to_csv("Weather Data.csv", encoding="utf-8", index=False)
weather_data.head()
# Out:
#            City Country        Date  Longitude  Latitude  Cloudiness  \
# 0    Hammerfest      NO  1541447400      23.68     70.66          75
# 1       Mataura      NZ  1541450657     168.86    -46.19           0
# 2        Hobart      AU  1541449800     147.33    -42.88          75
# 3    Nikolskoye      RU  1541448000      30.79     59.70          90
# 4  Punta Arenas      CL  1541448000     -70.91    -53.16          40
#
#    Humidity  Max Temp  Wind Speed
# 0        93     47.46       36.91
# 1        75     59.54        4.72
# 2        82     55.40        4.34
# 3        93     35.60        4.47
# 4        45     46.40       29.97

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
lats = weather_data["Latitude"]
temp = weather_data["Max Temp"]

plt.scatter(lats, temp, marker="o", facecolors="blue", edgecolors="black")
plt.ylim(-10, 105)
plt.xlim(-60, 85)

plt.title("City Latitudes vs Max Temperature")
plt.xlabel("City Latitudes")
plt.ylabel("Max Temperature (F)")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
lats = weather_data["Latitude"]
humidity = weather_data["Humidity"]

plt.scatter(lats, humidity, marker="o", facecolors="blue", edgecolors="black")
plt.ylim(-10, 105)
plt.xlim(-60, 85)

plt.title("City Latitudes vs Humidity")
plt.xlabel("City Latitudes")
plt.ylabel("Humidity")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
lats = weather_data["Latitude"]
cloudiness = weather_data["Cloudiness"]

plt.scatter(lats, cloudiness, marker="o", facecolors="blue", edgecolors="black")
plt.ylim(-10, 105)
plt.xlim(-60, 85)

plt.title("City Latitudes vs Cloudiness")
plt.xlabel("City Latitudes")
plt.ylabel("Cloudiness")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
lats = weather_data["Latitude"]
winds = weather_data["Wind Speed"]

plt.scatter(lats, winds, marker="o", facecolors="blue", edgecolors="black")
plt.ylim(-5, 40)
plt.xlim(-60, 85)

plt.title("City Latitudes vs Wind Speed")
plt.xlabel("City Latitudes")
plt.ylabel("Wind Speed (mph)")

plt.show()
